# %%
import pandas as pd
import requests
import json
from selenium import webdriver
from bs4 import BeautifulSoup

ETF_link = []

# %%
with open(r'C:\Users\KOJ\PycharmProjects\untitled\GitMaster\auto_Investment/auth.json', 'r') as f:
    auth = json.load(f)

url = "https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com"
driver = webdriver.Chrome(executable_path=r'C:\Users\KOJ\PycharmProjects\untitled\GitMaster\auto_Investment\chromedriver')
driver.get(url)
driver.find_element_by_name('id').send_keys('luper_')
driver.find_element_by_name('pw').send_keys('clxhtm9')
driver.find_element_by_id('log.login').click()

# %%
s = requests.Session()

# %%
for cookie in driver.get_cookies():
    s.cookies.set(cookie['name'], cookie['value'])

# %%
mail_url = "https://mail.naver.com/"
result = s.get(mail_url).text

# %%
soup = BeautifulSoup(result, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/css/mail2_le.min.210223.css" rel="stylesheet" type="text/css"/>
# <link href="/css/mail_skin.min.210223.css" rel="stylesheet" type="text/css"/>
# <link href="//ssl.pstatic.net" rel="dns-prefetch">
# <link href="//lcs.naver.com" rel="dns-prefetch">
# <link href="//cc.naver.com" rel="dns-prefetch"/>
# <link href="//static.nid.naver.com" rel="dns-prefetch"/>
# <link href="//phinf.pstatic.net" rel="dns-prefetch"/>
# <link href="/css/mail_me.min.210223.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon"/>
# <title>네이버 메일</title>
# <script type="text/javascript">
#
#
#
# 		var gnb_service = "mail";
# 		var gnb_logout = "http://www.naver.com";
# 		var gnb_template = "gnb_utf8";
# 		var gnb_brightness = 3;
# 		var gnb_item_hide_option = 8;
# 		var gnb_one_naver = 1;
#
# ...
